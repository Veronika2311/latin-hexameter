# %% [markdown]
# # Деление на стопы и поиск пробелов

# %%
import os

# %%
import os
import re
import copy

# %%
def givefiles(path):
    for d, dirs, files in os.walk(path):
        return files

# %%
def readfiles(path, file):
    file = os.path.join(path, file)
    with open(file, 'r', encoding='utf-8') as f:
        text = f.read()
        return text

# %%
def diftrepl(st): #замена дифтонгов
    verserepl = copy.copy(st)
    for i, let in enumerate(list(verserepl)):
        if let = 'u':
            if verserepl
        
    verserepl = re.sub('ae', 'ѣ', verserepl)
    verserepl = re.sub('Ae', 'Ѣ', verserepl)
    verserepl = re.sub('oe', 'ө', verserepl)
    verserepl = re.sub('Oe', 'Ө', verserepl)
    verserepl = re.sub('eu', 'ә', verserepl)
    verserepl = re.sub('Eu', 'Ә', verserepl)
    verserepl = re.sub('au', 'ү', verserepl)
    verserepl = re.sub('Au', 'Ү', verserepl)
    return verserepl

# %%
def caesurus(verse, feet):
    
    print(verse)
    splitvoices = re.split('a|e|u|y|o|i|ā|ē|ū|ȳ|ō|ī|ѣ|ө|ә|ү|A|E|U|Y|O|I|Ā|Ē|Ū|Ȳ|Ō|Ī|Ѣ|Ө|Ә|Ү', verse)
    print(splitvoices)
    spaceafters =  []
    for i, el in enumerate(splitvoices):
        if ' ' in el:
            spaceafters.append(i - 1)
    print(spaceafters)
    
    
    print(feet)
    allscheme = []        
    for i, letter in enumerate(list(copy.copy(feet))):
        if letter == 'D':
            scheme = ['a', 'b', 'c']
        elif letter == 'S':
            scheme = ['a', 'c']
        elif letter == 'T':
            scheme = ['a', 'b']
        else:
            print('Help! ', letter)
        finscheme = []
        for el in scheme:
            el = str(i + 1) + el
            finscheme.append(el)
        allscheme.extend(finscheme)       
    print(allscheme)
    
    if len(allscheme) == len(splitvoices) - 1:
        spacesheme = []
        for num in spaceafters:
            spacesheme.append(allscheme[num])
    else:
        print(len(allscheme))
        print(len(splitvoices))
        spacesheme = 'ОШИБКА'
    
    return spacesheme

# %%
def basefirst(path, filename, number):
    allinfile = {}
    text = readfiles(path, filename).split('\n')
    #print(text)
    steps = text[-1].split('FEETSTART')[1].split('FEETEND')[0].split(';')
    #print(steps)
    for i, st in enumerate(text[:-1]):
        #print(st)
        oneverse = {}
        #oneverse['id'] = number + 1
        #number = number + 1
        oneverse['verse'] = st
        oneverse['feet'] = steps[i]
        oneverse['file'] = filename
        oneverse['diftrepl'] = diftrepl(st) #возвращает строку с замененными дифтонгами
        #print(diftrepl(st))
        oneverse['caesurs'] = caesurus(oneverse['diftrepl'], oneverse['feet']) #дв список пробелов
  
        #print(caesurus(oneverse['diftrepl'], oneverse['feet']))
        #print(oneverse)
        #print('aaaaaaaaaa')

# %%
basefirst('C:/Users/M/Desktop/', '1.txt', 0)
# Out:
# Ѣtna mihī ruptīqwe cavīs fornācibus ignēs
# ['', 'tn', ' m', 'h', ' r', 'pt', 'qw', ' c', 'v', 's f', 'rn', 'c', 'b', 's ', 'gn', 's ']
# [1, 3, 6, 8, 12, 14]
# DSDSDS
# ['1a', '1b', '1c', '2a', '2c', '3a', '3b', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1b', '2a', '3b', '4a', '5c', '6c']
# et qwѣ tam fortēs volvant incendia cүsѣ
# ['', 't qw', ' t', 'm f', 'rt', 's v', 'lv', 'nt ', 'nc', 'nd', '', ' c', 's', ' ']
# [0, 1, 2, 4, 6, 10, 12]
# SSSSDS
# ['1a', '1c', '2a', '2c', '3a', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1a', '1c', '2a', '3a', '4a', '5c', '6c']
# qwid fremat imperium qwid rүcōs torqweat ѣstūs
# ['qw', 'd fr', 'm', 't ', 'mp', 'r', '', 'm qw', 'd r', 'c', 's t', 'rqw', '', 't ', 'st', 's ']
# [0, 2, 6, 7, 9, 12, 14]
# DDSSDS
# ['1a', '1b', '1c', '2a', '2b', '2c', '3a', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1a', '1c', '3a', '3c', '4c', '5c', '6c']
# carmen erit. dexter veniās mihi carminis үctor
# ['c', 'rm', 'n ', 'r', 't. d', 'xt', 'r v', 'n', '', 's m', 'h', ' c', 'rm', 'n', 's ', 'ct', 'r ']
# [1, 3, 5, 8, 10, 13, 15]
# DSDDDT
# ['1a', '1b', '1c', '2a', '2c', '3a', '3b', '3c', '4a', '4b', '4c', '5a', '5b', '5c', '6a', '6b']
# ['1b', '2a', '3a', '4a', '4c', '5c', '6b']
# Help!
# sә tibi Dōdōnē potior tēcumqwe faventēs
# ['s', ' t', 'b', ' D', 'd', 'n', ' p', 't', '', 'r t', 'c', 'mqw', ' f', 'v', 'nt', 's ']
# [0, 2, 5, 8, 11, 14]
# DSDSDS
# ['1a', '1b', '1c', '2a', '2c', '3a', '3b', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1a', '1c', '3a', '4a', '5b', '6c']
# in nova Pīeriō properent ā fonte sorōrēs
# ['', 'n n', 'v', ' P', '', 'r', '', ' pr', 'p', 'r', 'nt ', ' f', 'nt', ' s', 'r', 'r', 's ']
# [0, 2, 6, 9, 10, 12, 15]
# DDDSDS
# ['1a', '1b', '1c', '2a', '2b', '2c', '3a', '3b', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1a', '1c', '3a', '4a', '4c', '5b', '6c']
# vōta: per īnsolitum Phөbō duce tūtius ītur.
# ['v', 't', ': p', 'r ', 'ns', 'l', 't', 'm Ph', 'b', ' d', 'c', ' t', 't', '', 's ', 't', 'r. ']
# [1, 2, 6, 8, 10, 13, 15]
# DDSDDT
# ['1a', '1b', '1c', '2a', '2b', '2c', '3a', '3c', '4a', '4b', '4c', '5a', '5b', '5c', '6a', '6b']
# ['1b', '1c', '3a', '4a', '4c', '5c', '6b']
# үrea sēcūrī qwis nescit sѣcula rēgis
# ['', 'r', '', ' s', 'c', 'r', ' qw', 's n', 'sc', 't s', 'c', 'l', ' r', 'g', 's ']
# [2, 5, 6, 8, 11, 13]
# DSSSDT
# ['1a', '1b', '1c', '2a', '2c', '3a', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6b']
# ['1c', '3a', '3c', '4c', '5c', '6b']
# cum domitīs nēmō Cererem jactāret in arvīs
# ['c', 'm d', 'm', 't', 's n', 'm', ' C', 'r', 'r', 'm j', 'ct', 'r', 't ', 'n ', 'rv', 's ']
# [0, 3, 5, 8, 11, 12, 14]
# DSDSDS
# ['1a', '1b', '1c', '2a', '2c', '3a', '3b', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1a', '2a', '3a', '4a', '5b', '5c', '6c']
# ventūrīsqwe malās prohibēret frūctibus herbās
# ['v', 'nt', 'r', 'sqw', ' m', 'l', 's pr', 'h', 'b', 'r', 't fr', 'ct', 'b', 's h', 'rb', 's ']
# [3, 5, 9, 12, 14]
# SDDSDS
# ['1a', '1c', '2a', '2b', '2c', '3a', '3b', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['2b', '3a', '4c', '5c', '6c']
# annua sed saturѣ complērent horrea messēs
# ['', 'nn', '', ' s', 'd s', 't', 'r', ' c', 'mpl', 'r', 'nt h', 'rr', '', ' m', 'ss', 's ']
# [2, 3, 6, 9, 12, 14]
# DDSSDS
# ['1a', '1b', '1c', '2a', '2b', '2c', '3a', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1c', '2a', '3a', '4c', '5c', '6c']
# ipse suō flueret Bacchus pede mellaqwe lentīs
# ['', 'ps', ' s', '', ' fl', '', 'r', 't B', 'cch', 's p', 'd', ' m', 'll', 'qw', ' l', 'nt', 's ']
# [1, 3, 6, 8, 10, 13, 15]
# DDSDDS
# ['1a', '1b', '1c', '2a', '2b', '2c', '3a', '3c', '4a', '4b', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1b', '2a', '3a', '4a', '4c', '5c', '6c']
# pendērent foliīs et pinguī Pallas olīvā
# ['p', 'nd', 'r', 'nt f', 'l', '', 's ', 't p', 'ng', '', ' P', 'll', 's ', 'l', 'v', ' ']
# [2, 5, 6, 9, 11, 14]
# SDSSDS
# ['1a', '1c', '2a', '2b', '2c', '3a', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# 14
# 16
# ОШИБКА
# sēcrētōs amnīs ageret tum grātia rūris?
# ['s', 'cr', 't', 's ', 'mn', 's ', 'g', 'r', 't t', 'm gr', 't', '', ' r', 'r', 's? ']
# [2, 4, 7, 8, 11, 13]
# SSDSDT
# ['1a', '1c', '2a', '2c', '3a', '3b', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6b']
# ['2a', '3a', '4a', '4c', '5c', '6b']
# nōn cessit cuīqwam melius sua tempora nōsse.
# ['n', 'n c', 'ss', 't c', '', 'qw', 'm m', 'l', '', 's s', '', ' t', 'mp', 'r', ' n', 'ss', '. ']
# [0, 2, 5, 8, 10, 13, 15]
# SSDDDT
# ['1a', '1c', '2a', '2c', '3a', '3b', '3c', '4a', '4b', '4c', '5a', '5b', '5c', '6a', '6b']
# 15
# 17
# ОШИБКА
# ultima qwis tacuit juvenum certāmina Colchōs?
# ['', 'lt', 'm', ' qw', 's t', 'c', '', 't j', 'v', 'n', 'm c', 'rt', 'm', 'n', ' C', 'lch', 's? ']
# [2, 3, 6, 9, 13, 15]
# DDDSDS
# ['1a', '1b', '1c', '2a', '2b', '2c', '3a', '3b', '3c', '4a', '4c', '5a', '5b', '5c', '6a', '6c']
# ['1c', '2a', '3a', '4a', '5c', '6c']
